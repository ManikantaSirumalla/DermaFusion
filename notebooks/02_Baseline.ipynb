# %% [markdown]
# # 02 - Baseline (Image-Only) Experiments
#
# Guide-aligned: image-only baselines for EfficientNet-B4, Swin-T, ConvNeXt-V2 (A1–A3).
#
# - Train image-only models with GroupKFold-safe splits.
# - Report balanced accuracy, macro F1, per-class metrics.
# - Use as reference for multi-modal and ablation experiments.

# %%
# Run training or load results from outputs/
from pathlib import Path
print("Baseline experiments: run scripts/train.py with experiment=baseline")
Path(".").resolve()
