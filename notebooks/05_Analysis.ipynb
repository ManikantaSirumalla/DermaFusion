# %% [markdown]
# # 05 - Final Analysis (Guide)
#
# - Ablation comparison (A1–E2).
# - Confusion matrices, ROC curves, reliability diagrams.
# - GradCAM and attention visualizations.
# - Failure case taxonomy and confidence distribution.
# - Fairness audit (sex, age, location).

# %%
from pathlib import Path
Path(".").resolve()
